# %%
import os
import pandas as pd
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import hashlib
import sklearn as sk
import os
import time
import datetime

# %%
path = '/home/catherinej/Downloads'
file = os.path.join(path, 'IrmaMudThicknessComparisons - Original Data.csv')
mud = pd.read_csv(file)
mud
# mud.head()
# mud.info()
# mud.describe()
# Out:
#     Region Site  Station      Date 1     Date 2 Thickness at Date 1 (cm)  \
# 0      TTI  CCB   CC1 S1  12/20/2017  1/28/2018                        0
# 1      TTI  CCB   CC1 S2  12/20/2017        NaN                        0
# 2      TTI  CCB   CC1 S3  12/20/2017        NaN                        0
# 3      TTI  CCB   CC1 S4  12/20/2017        NaN                       40
# 4      TTI  CCB   CC2 S1  12/20/2017  1/28/2018                        0
# 5      TTI  CCB   CC2 S2  12/20/2017        NaN                        0
# 6      TTI  CCB   CC2 S3  12/20/2017        NaN                        0
# 7      TTI  CCB   CC2 S4  12/20/2017        NaN                        0
# 8      TTI  CCB   CC3 S1  12/20/2017  1/28/2018                        0
# 9      TTI  CCB   CC3 S2  12/20/2017        NaN                        0
# 10     TTI  CCB   CC3 S3  12/20/2017        NaN                        0
# 11     TTI  CCB   CC3 S4  12/20/2017        NaN                        0
# 12     TTI  BW2   BW2 S1  12/19/2017  1/28/2018                        9
# 13     TTI  BW2   BW2 S2  12/19/2017  1/28/2018                       11
# 14     TTI  BW2   BW2 S3  12/19/2017  1/28/2018                        2
# 15     TTI  BW2   BW2 S4  12/19/2017  1/28/2018                        2
# 16     TTI  BW2   BW2 S5  12/19/2017  1/28/2018                        5
# 17     TTI  BW2   BW2 S6  12/19/2017  1/28/2018                        2
# 18     TTI  BW2   BW2 S7  12/19/2017  1/28/2018                        2
# 19     TTI  BW2   BW2 S8  12/19/2017  1/28/2018                        3
# 20     TTI  BW2   BW2 S9  12/19/2017  1/28/2018                        9
# 21     TTI  BW2  BW2 S10  12/19/2017  1/28/2018                        6
# 22     TTI  BW2  BW2 S11  12/19/2017  1/28/2018                        3
# 23     TTI  BW2  BW2 S12  12/19/2017  1/28/2018                        4
# 24     TTI  BW3   BW3 S1  12/19/2017  1/28/2018                        6
# 25     TTI  BW3   BW3 S2  12/19/2017  1/28/2018                        3
# 26     TTI  BW3   BW3 S3  12/19/2017  1/28/2018                        3
# 27     TTI  BW3   BW3 S4  12/19/2017  1/28/2018                        3
# 28     TTI  BW3   BW3 S5  12/19/2017  1/28/2018                        2
# 29     TTI  BW3   BW3 S6  12/19/2017  1/28/2018                        2
# ..     ...  ...      ...         ...        ...                      ...
# 100    LFK  LAD       S1  11/18/2017  3/14/2018                        1
# 101    LFK  LAD       S2  11/18/2017  3/14/2018                     0.25
# 102    LFK  LAD       S3  11/18/2017  3/14/2018                      0.5
# 103    LFK  LAD       S4  11/18/2017  3/14/2018                        2
# 104    LFK  LAD       S5  11/18/2017  3/14/2018                        5
# 105    LFK  LAD       S6  11/18/2017  3/14/2018                        2
# 106    LFK  LAD       S7  11/18/2017  3/14/2018                        2
# 107    LFK  LAD       S8  11/18/2017  3/14/2018                        1
# 108    LFK  LAD       S9  11/18/2017  3/14/2018                     <0.1
# 109    LFK  LAD      S10  11/18/2017  3/14/2018                      0.1
# 110    LFK  LAD      S11  11/18/2017  3/14/2018                     <0.1
# 111    LFK  LAD      S12  11/18/2017  3/14/2018                        1
# 112    LFK  LAD      S13  11/18/2017  3/14/2018                        1
# 113    LFK  LAD      S14  11/18/2017  3/14/2018                        5
# 114    LFK  LAD      S15  11/18/2017  3/14/2018                      NaN
# 115    LFK  WTZ       S1  11/19/2017  3/14/2018                       <1
# 116    LFK  WTZ       S2  11/19/2017  3/14/2018                       <1
# 117    LFK  WTZ       S3  11/19/2017  3/14/2018                       <1
# 118    LFK  WTZ       S4  11/19/2017  3/14/2018                      0.2
# 119    LFK  WTZ       S5  11/19/2017  3/14/2018                     <0.1
# 120    LFK  WTZ       S6  11/19/2017  3/14/2018                      0.2
# 121    LFK  WTZ       S7  11/19/2017  3/14/2018                      0.2
# 122    LFK  WTZ       S8  11/19/2017  3/14/2018                      0.2
# 123    LFK  WTZ       S9  11/19/2017  3/14/2018                      0.3
# 124    LFK  WTZ      S10  11/19/2017  3/14/2018                      0.2
# 125    LFK  WTZ      S11  11/19/2017  3/14/2018                     0.75
# 126    LFK  WTZ      S12  11/19/2017  3/14/2018                        4
# 127    NaN  NaN      NaN         NaN        NaN                      NaN
# 128    NaN  NaN      NaN         NaN        NaN                      NaN
# 129    NaN  NaN      NaN         NaN        NaN                      NaN
#
#      Thickness at Date 2 (cm) Thickness at Date 3 (cm)       Lat       Lon  \
# 0                        0.00                        0  26.02238 -81.73427
# 1                         NaN                        0  26.02240 -81.73423
# 2                         NaN                        0  26.02230 -81.73427
# 3                         NaN                      NaN  26.02232 -81.73418
# 4                        0.00                        0  26.02202 -81.73415
# 5                         NaN                        0  26.02203 -81.73413
# 6                         NaN                        0  26.02207 -81.73410
# 7                         NaN                      NaN  26.02208 -81.73412
# 8                        0.00                        0  26.02143 -81.73410
# 9                         NaN                        0  26.02143 -81.73402
# 10                        NaN                        0  26.02135 -81.73408
# 11                        NaN                      NaN  26.02135 -81.73403
# 12                       4.00                        6  25.92489 -81.60935
# 13                       6.50                        2  25.92488 -81.60933
# 14                       6.50                      2.5  25.92490 -81.60927
# 15                       3.00                      3.5  25.92485 -81.60921
# 16                       3.00                        3  25.92484 -81.60919
# 17                       4.00                        2  25.92481 -81.60925
# 18                       1.00                        2  25.92482 -81.60931
# 19                       4.00                      1.5  25.92486 -81.60934
# 20                       5.50                        6  25.92488 -81.60933
# 21                       5.50                      4.5  25.92484 -81.60934
# 22                       3.50                        3  25.92479 -81.60931
# 23                       4.50                        2  25.92474 -81.60926
# 24                       1.75                        3  25.92365 -81.61239
# 25                       1.50                        3  25.92359 -81.61248
# 26                       3.50                        1  25.92359 -81.61250
# 27                       2.00                        2  25.92354 -81.61254
# 28                       2.00                        2  25.92348 -81.61263
# 29                       2.00                      2.5  25.92343 -81.61269
# ..                        ...                      ...       ...       ...
# 100                       NaN                        1       NaN       NaN
# 101                       NaN                        1       NaN       NaN
# 102                       NaN                     <0.1       NaN       NaN
# 103                       NaN                     <0.1       NaN       NaN
# 104                       NaN                     <0.1       NaN       NaN
# 105                       NaN                     <0.1       NaN       NaN
# 106                       NaN                     <0.1       NaN       NaN
# 107                       NaN                     <0.1       NaN       NaN
# 108                       NaN                     <0.1       NaN       NaN
# 109                       NaN                     <0.1       NaN       NaN
# 110                       NaN                        1       NaN       NaN
# 111                       NaN                        2       NaN       NaN
# 112                       NaN                      6.5       NaN       NaN
# 113                       NaN                        2       NaN       NaN
# 114                       NaN                        1       NaN       NaN
# 115                      1.00                        0  24.64750 -81.65353
# 116                      1.00                      0.5  24.64760 -81.65360
# 117                      0.00                     <0.1  24.64763 -81.65363
# 118                      0.00                      7.5  24.64763 -81.65366
# 119                      1.00                        0  24.64765 -81.65372
# 120                      0.50                      0.5  24.64765 -81.65377
# 121                      0.50                        0  24.64769 -81.65378
# 122                      0.50                     <0.1  24.64768 -81.65382
# 123                      0.20                     0.75  24.64770 -81.65384
# 124                      0.20                      0.5  24.64770 -81.65386
# 125                      0.50                        0  24.64770 -81.65390
# 126                      0.50                     <0.1  24.64771 -81.65391
# 127                       NaN                     0.75       NaN       NaN
# 128                       NaN                      1.5       NaN       NaN
# 129                       NaN                      1.5       NaN       NaN
#
#      water_lat  water_lon Notes Unnamed: 13
# 0    26.021769 -81.734467   NaN         NaN
# 1    26.021769 -81.734467   NaN         NaN
# 2    26.021769 -81.734467   NaN         NaN
# 3    26.021769 -81.734467   NaN         NaN
# 4    26.021769 -81.734467   NaN         NaN
# 5    26.021769 -81.734467   NaN         NaN
# 6    26.021769 -81.734467   NaN         NaN
# 7    26.021769 -81.734467   NaN         NaN
# 8    26.021769 -81.734467   NaN         NaN
# 9    26.021769 -81.734467   NaN         NaN
# 10   26.021769 -81.734467   NaN         NaN
# 11   26.021769 -81.734467   NaN         NaN
# 12   25.924941 -81.609406   NaN         NaN
# 13   25.924941 -81.609406   NaN         NaN
# 14   25.924941 -81.609406   NaN         NaN
# 15   25.924941 -81.609406   NaN         NaN
# 16   25.924941 -81.609406   NaN         NaN
# 17   25.924941 -81.609406   NaN         NaN
# 18   25.924941 -81.609406   NaN         NaN
# 19   25.924941 -81.609406   NaN         NaN
# 20   25.924941 -81.609406   NaN         NaN
# 21   25.924941 -81.609406   NaN         NaN
# 22   25.924941 -81.609406   NaN         NaN
# 23   25.924941 -81.609406   NaN         NaN
# 24   25.922184 -81.613476   NaN         NaN
# 25   25.922184 -81.613476   NaN         NaN
# 26   25.922184 -81.613476   NaN         NaN
# 27   25.922184 -81.613476   NaN         NaN
# 28   25.922184 -81.613476   NaN         NaN
# 29   25.922184 -81.613476   NaN         NaN
# ..         ...        ...   ...         ...
# 100        NaN        NaN   NaN         NaN
# 101        NaN        NaN   NaN         NaN
# 102        NaN        NaN   NaN         NaN
# 103        NaN        NaN   NaN         NaN
# 104        NaN        NaN   NaN         NaN
# 105        NaN        NaN   NaN         NaN
# 106        NaN        NaN   NaN         NaN
# 107        NaN        NaN   NaN         NaN
# 108        NaN        NaN   NaN         NaN
# 109        NaN        NaN   NaN         NaN
# 110        NaN        NaN   NaN         NaN
# 111        NaN        NaN   NaN         NaN
# 112        NaN        NaN   NaN         NaN
# 113        NaN        NaN   NaN         NaN
# 114        NaN        NaN   NaN         NaN
# 115  24.647714 -81.653949   NaN         NaN
# 116  24.647714 -81.653949   NaN         NaN
# 117  24.647714 -81.653949   NaN         NaN
# 118  24.647714 -81.653949   NaN         NaN
# 119  24.647714 -81.653949   NaN         NaN
# 120  24.647714 -81.653949   NaN         NaN
# 121  24.647714 -81.653949   NaN         NaN
# 122  24.647714 -81.653949   NaN         NaN
# 123  24.647714 -81.653949   NaN         NaN
# 124  24.647714 -81.653949   NaN         NaN
# 125  24.647714 -81.653949   NaN         NaN
# 126  24.647714 -81.653949   NaN         NaN
# 127        NaN        NaN   NaN         NaN
# 128        NaN        NaN   NaN         NaN
# 129        NaN        NaN   NaN         NaN
#
# [130 rows x 14 columns]

# %%
# t = datetime.datetime()
mud['Date 1'] =  mud['Date 1'].dt.total_seconds()
# for dates in mud['Date 1']:
#     t = datetime.datetime.fromtimestamp(dates)
#   year, month, day   t = datetime.datetime(dates)
#     print(t)
# >>> t = datetime.datetime(2011, 10, 21, 0, 0)
# >>> time.mktime(t.timetuple())
# 1319148000.0
# for dates in mud['Date 1']:
#     dates.total_seconds
#     year, month, day, hour, minutes, seconds = dates
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-33c7347db8f1> in <module>()
#       1 # t = datetime.datetime()
# ----> 2 mud['Date 1'] =  mud['Date 1'].dt.total_seconds()
#       3 # for dates in mud['Date 1']:
#       4 #     t = datetime.datetime.fromtimestamp(dates)
#       5 #   year, month, day   t = datetime.datetime(dates)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     323             pass  # we raise an attribute error anyway
#     324
# --> 325         raise AttributeError("Can only use .dt accessor with datetimelike "
#     326                              "values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
mud.hist(bins=50, figsize=(5,5))
plt.show()

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit()
for train_index, test_index in split.split(mud, mud['Site']):
    mud_train_set = mud.loc[train_index]
    mud_test_set = mud.loc[test_index]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-b8b6671ecc0e> in <module>()
#       1 from sklearn.model_selection import StratifiedShuffleSplit
#       2 split = StratifiedShuffleSplit()
# ----> 3 for train_index, test_index in split.split(mud, mud['Site']):
#       4     mud_train_set = mud.loc[train_index]
#       5     mud_test_set = mud.loc[test_index]
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     931         """
#     932         X, y, groups = indexable(X, y, groups)
# --> 933         for train, test in self._iter_indices(X, y, groups):
#     934             yield train, test
#     935
#
# ~/.local/lib/python3.6/site-packages/sklearn/model_selection/_split.py in _iter_indices(self, X, y, groups)
#    1230         n_train, n_test = _validate_shuffle_split(n_samples, self.test_size,
#    1231                                                   self.train_size)
# -> 1232         classes, y_indices = np.unique(y, return_inverse=True)
#    1233         n_classes = classes.shape[0]
#    1234
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     231     ar = np.asanyarray(ar)
#     232     if axis is None:
# --> 233         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     234         return _unpack_tuple(ret)
#     235
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     276
#     277     if optional_indices:
# --> 278         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     279         aux = ar[perm]
#     280     else:
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
mud['Site'].value_counts()
# Out:
# UFU      20
# SNK      18
# CBD      18
# LAD      15
# BW2      12
# WTZ      12
# CCB      12
# BW3      10
# FBTBM    10
# Name: Site, dtype: int64

# %%
# mud.plot(kind='scatter', x='Lon', y="Lat", alpha=0.4,
#         cmap=plt.get_cmap('jet'), colorbar=True)
# plt.legend()

# %%
corr_matrix = mud.corr()
for key in corr_matrix:
    print(key)
corr_matrix['Thickness at Date 2 (cm)'].sort_values(ascending=False)
# Out:
# Thickness at Date 2 (cm)
# Lat
# Lon
# water_lat
# water_lon
# Thickness at Date 2 (cm)    1.000000
# water_lat                  -0.018481
# Lat                        -0.018557
# water_lon                  -0.102821
# Lon                        -0.103336
# Name: Thickness at Date 2 (cm), dtype: float64

# %%
attributes = ['Lat', 'Lon', 'Thickness at Date 1 (cm)', 'Thickness at Date 2 (cm)',
             ]

pd.tools.plotting.scatter_matrix(mud[attributes], figsize=(6,4))
# Out:
# /home/catherinej/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   after removing the cwd from sys.path.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f009df9c5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f009dfbc7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f009df65c18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f009df162e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f009df3d978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f009df3d9b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f009de966d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f009debfd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f009de70438>]],
#       dtype=object)

# %%
data = mud.drop('Notes', axis=1)
data.dropna(subset=['Thickness at Date 1 (cm)'])
data.dropna(subset=['Thickness at Date 2 (cm)'])
data
# Out:
#     Region Site  Station      Date 1     Date 2 Thickness at Date 1 (cm)  \
# 0      TTI  CCB   CC1 S1  12/20/2017  1/28/2018                        0
# 1      TTI  CCB   CC1 S2  12/20/2017        NaN                        0
# 2      TTI  CCB   CC1 S3  12/20/2017        NaN                        0
# 3      TTI  CCB   CC1 S4  12/20/2017        NaN                       40
# 4      TTI  CCB   CC2 S1  12/20/2017  1/28/2018                        0
# 5      TTI  CCB   CC2 S2  12/20/2017        NaN                        0
# 6      TTI  CCB   CC2 S3  12/20/2017        NaN                        0
# 7      TTI  CCB   CC2 S4  12/20/2017        NaN                        0
# 8      TTI  CCB   CC3 S1  12/20/2017  1/28/2018                        0
# 9      TTI  CCB   CC3 S2  12/20/2017        NaN                        0
# 10     TTI  CCB   CC3 S3  12/20/2017        NaN                        0
# 11     TTI  CCB   CC3 S4  12/20/2017        NaN                        0
# 12     TTI  BW2   BW2 S1  12/19/2017  1/28/2018                        9
# 13     TTI  BW2   BW2 S2  12/19/2017  1/28/2018                       11
# 14     TTI  BW2   BW2 S3  12/19/2017  1/28/2018                        2
# 15     TTI  BW2   BW2 S4  12/19/2017  1/28/2018                        2
# 16     TTI  BW2   BW2 S5  12/19/2017  1/28/2018                        5
# 17     TTI  BW2   BW2 S6  12/19/2017  1/28/2018                        2
# 18     TTI  BW2   BW2 S7  12/19/2017  1/28/2018                        2
# 19     TTI  BW2   BW2 S8  12/19/2017  1/28/2018                        3
# 20     TTI  BW2   BW2 S9  12/19/2017  1/28/2018                        9
# 21     TTI  BW2  BW2 S10  12/19/2017  1/28/2018                        6
# 22     TTI  BW2  BW2 S11  12/19/2017  1/28/2018                        3
# 23     TTI  BW2  BW2 S12  12/19/2017  1/28/2018                        4
# 24     TTI  BW3   BW3 S1  12/19/2017  1/28/2018                        6
# 25     TTI  BW3   BW3 S2  12/19/2017  1/28/2018                        3
# 26     TTI  BW3   BW3 S3  12/19/2017  1/28/2018                        3
# 27     TTI  BW3   BW3 S4  12/19/2017  1/28/2018                        3
# 28     TTI  BW3   BW3 S5  12/19/2017  1/28/2018                        2
# 29     TTI  BW3   BW3 S6  12/19/2017  1/28/2018                        2
# ..     ...  ...      ...         ...        ...                      ...
# 100    LFK  LAD       S1  11/18/2017  3/14/2018                        1
# 101    LFK  LAD       S2  11/18/2017  3/14/2018                     0.25
# 102    LFK  LAD       S3  11/18/2017  3/14/2018                      0.5
# 103    LFK  LAD       S4  11/18/2017  3/14/2018                        2
# 104    LFK  LAD       S5  11/18/2017  3/14/2018                        5
# 105    LFK  LAD       S6  11/18/2017  3/14/2018                        2
# 106    LFK  LAD       S7  11/18/2017  3/14/2018                        2
# 107    LFK  LAD       S8  11/18/2017  3/14/2018                        1
# 108    LFK  LAD       S9  11/18/2017  3/14/2018                     <0.1
# 109    LFK  LAD      S10  11/18/2017  3/14/2018                      0.1
# 110    LFK  LAD      S11  11/18/2017  3/14/2018                     <0.1
# 111    LFK  LAD      S12  11/18/2017  3/14/2018                        1
# 112    LFK  LAD      S13  11/18/2017  3/14/2018                        1
# 113    LFK  LAD      S14  11/18/2017  3/14/2018                        5
# 114    LFK  LAD      S15  11/18/2017  3/14/2018                      NaN
# 115    LFK  WTZ       S1  11/19/2017  3/14/2018                       <1
# 116    LFK  WTZ       S2  11/19/2017  3/14/2018                       <1
# 117    LFK  WTZ       S3  11/19/2017  3/14/2018                       <1
# 118    LFK  WTZ       S4  11/19/2017  3/14/2018                      0.2
# 119    LFK  WTZ       S5  11/19/2017  3/14/2018                     <0.1
# 120    LFK  WTZ       S6  11/19/2017  3/14/2018                      0.2
# 121    LFK  WTZ       S7  11/19/2017  3/14/2018                      0.2
# 122    LFK  WTZ       S8  11/19/2017  3/14/2018                      0.2
# 123    LFK  WTZ       S9  11/19/2017  3/14/2018                      0.3
# 124    LFK  WTZ      S10  11/19/2017  3/14/2018                      0.2
# 125    LFK  WTZ      S11  11/19/2017  3/14/2018                     0.75
# 126    LFK  WTZ      S12  11/19/2017  3/14/2018                        4
# 127    NaN  NaN      NaN         NaN        NaN                      NaN
# 128    NaN  NaN      NaN         NaN        NaN                      NaN
# 129    NaN  NaN      NaN         NaN        NaN                      NaN
#
#      Thickness at Date 2 (cm) Thickness at Date 3 (cm)       Lat       Lon  \
# 0                        0.00                        0  26.02238 -81.73427
# 1                         NaN                        0  26.02240 -81.73423
# 2                         NaN                        0  26.02230 -81.73427
# 3                         NaN                      NaN  26.02232 -81.73418
# 4                        0.00                        0  26.02202 -81.73415
# 5                         NaN                        0  26.02203 -81.73413
# 6                         NaN                        0  26.02207 -81.73410
# 7                         NaN                      NaN  26.02208 -81.73412
# 8                        0.00                        0  26.02143 -81.73410
# 9                         NaN                        0  26.02143 -81.73402
# 10                        NaN                        0  26.02135 -81.73408
# 11                        NaN                      NaN  26.02135 -81.73403
# 12                       4.00                        6  25.92489 -81.60935
# 13                       6.50                        2  25.92488 -81.60933
# 14                       6.50                      2.5  25.92490 -81.60927
# 15                       3.00                      3.5  25.92485 -81.60921
# 16                       3.00                        3  25.92484 -81.60919
# 17                       4.00                        2  25.92481 -81.60925
# 18                       1.00                        2  25.92482 -81.60931
# 19                       4.00                      1.5  25.92486 -81.60934
# 20                       5.50                        6  25.92488 -81.60933
# 21                       5.50                      4.5  25.92484 -81.60934
# 22                       3.50                        3  25.92479 -81.60931
# 23                       4.50                        2  25.92474 -81.60926
# 24                       1.75                        3  25.92365 -81.61239
# 25                       1.50                        3  25.92359 -81.61248
# 26                       3.50                        1  25.92359 -81.61250
# 27                       2.00                        2  25.92354 -81.61254
# 28                       2.00                        2  25.92348 -81.61263
# 29                       2.00                      2.5  25.92343 -81.61269
# ..                        ...                      ...       ...       ...
# 100                       NaN                        1       NaN       NaN
# 101                       NaN                        1       NaN       NaN
# 102                       NaN                     <0.1       NaN       NaN
# 103                       NaN                     <0.1       NaN       NaN
# 104                       NaN                     <0.1       NaN       NaN
# 105                       NaN                     <0.1       NaN       NaN
# 106                       NaN                     <0.1       NaN       NaN
# 107                       NaN                     <0.1       NaN       NaN
# 108                       NaN                     <0.1       NaN       NaN
# 109                       NaN                     <0.1       NaN       NaN
# 110                       NaN                        1       NaN       NaN
# 111                       NaN                        2       NaN       NaN
# 112                       NaN                      6.5       NaN       NaN
# 113                       NaN                        2       NaN       NaN
# 114                       NaN                        1       NaN       NaN
# 115                      1.00                        0  24.64750 -81.65353
# 116                      1.00                      0.5  24.64760 -81.65360
# 117                      0.00                     <0.1  24.64763 -81.65363
# 118                      0.00                      7.5  24.64763 -81.65366
# 119                      1.00                        0  24.64765 -81.65372
# 120                      0.50                      0.5  24.64765 -81.65377
# 121                      0.50                        0  24.64769 -81.65378
# 122                      0.50                     <0.1  24.64768 -81.65382
# 123                      0.20                     0.75  24.64770 -81.65384
# 124                      0.20                      0.5  24.64770 -81.65386
# 125                      0.50                        0  24.64770 -81.65390
# 126                      0.50                     <0.1  24.64771 -81.65391
# 127                       NaN                     0.75       NaN       NaN
# 128                       NaN                      1.5       NaN       NaN
# 129                       NaN                      1.5       NaN       NaN
#
#      water_lat  water_lon Unnamed: 13
# 0    26.021769 -81.734467         NaN
# 1    26.021769 -81.734467         NaN
# 2    26.021769 -81.734467         NaN
# 3    26.021769 -81.734467         NaN
# 4    26.021769 -81.734467         NaN
# 5    26.021769 -81.734467         NaN
# 6    26.021769 -81.734467         NaN
# 7    26.021769 -81.734467         NaN
# 8    26.021769 -81.734467         NaN
# 9    26.021769 -81.734467         NaN
# 10   26.021769 -81.734467         NaN
# 11   26.021769 -81.734467         NaN
# 12   25.924941 -81.609406         NaN
# 13   25.924941 -81.609406         NaN
# 14   25.924941 -81.609406         NaN
# 15   25.924941 -81.609406         NaN
# 16   25.924941 -81.609406         NaN
# 17   25.924941 -81.609406         NaN
# 18   25.924941 -81.609406         NaN
# 19   25.924941 -81.609406         NaN
# 20   25.924941 -81.609406         NaN
# 21   25.924941 -81.609406         NaN
# 22   25.924941 -81.609406         NaN
# 23   25.924941 -81.609406         NaN
# 24   25.922184 -81.613476         NaN
# 25   25.922184 -81.613476         NaN
# 26   25.922184 -81.613476         NaN
# 27   25.922184 -81.613476         NaN
# 28   25.922184 -81.613476         NaN
# 29   25.922184 -81.613476         NaN
# ..         ...        ...         ...
# 100        NaN        NaN         NaN
# 101        NaN        NaN         NaN
# 102        NaN        NaN         NaN
# 103        NaN        NaN         NaN
# 104        NaN        NaN         NaN
# 105        NaN        NaN         NaN
# 106        NaN        NaN         NaN
# 107        NaN        NaN         NaN
# 108        NaN        NaN         NaN
# 109        NaN        NaN         NaN
# 110        NaN        NaN         NaN
# 111        NaN        NaN         NaN
# 112        NaN        NaN         NaN
# 113        NaN        NaN         NaN
# 114        NaN        NaN         NaN
# 115  24.647714 -81.653949         NaN
# 116  24.647714 -81.653949         NaN
# 117  24.647714 -81.653949         NaN
# 118  24.647714 -81.653949         NaN
# 119  24.647714 -81.653949         NaN
# 120  24.647714 -81.653949         NaN
# 121  24.647714 -81.653949         NaN
# 122  24.647714 -81.653949         NaN
# 123  24.647714 -81.653949         NaN
# 124  24.647714 -81.653949         NaN
# 125  24.647714 -81.653949         NaN
# 126  24.647714 -81.653949         NaN
# 127        NaN        NaN         NaN
# 128        NaN        NaN         NaN
# 129        NaN        NaN         NaN
#
# [130 rows x 13 columns]

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(strategy='median')
mud_num = data.drop('Region', axis=1)
mud_num = mud_num.drop('Site', axis=1)
mud_num = mud_num.drop('Station', axis=1)
mud_num = mud_num.dropna(subset=['Date 2'])
# 91                         0  24.65010 -81.59641  24.653879 -81.596217
# 92                         0  24.65005 -81.59642  24.653879 -81.596217
# 93                         0  24.65002 -81.59641  24.653879 -81.596217
# 94                         0  24.64998 -81.59646  24.653879 -81.596217
# 95                         0  24.64998 -81.59646  24.653879 -81.596217
# 96                         0  24.64994 -81.59644  24.653879 -81.596217
# 97                         0  24.64988 -81.59642  24.653879 -81.596217
# 98                         0  24.64989 -81.59642  24.653879 -81.596217
# 99                         0  24.64994 -81.59644  24.653879 -81.596217
# 115                        0  24.64750 -81.65353  24.647714 -81.653949
# 116                      0.5  24.64760 -81.65360  24.647714 -81.653949
# 117                        0  24.64763 -81.65363  24.647714 -81.653949
# 118                      7.5  24.64763 -81.65366  24.647714 -81.653949
# 119                        0  24.64765 -81.65372  24.647714 -81.653949
# 120                      0.5  24.64765 -81.65377  24.647714 -81.653949
# 121                        0  24.64769 -81.65378  24.647714 -81.653949
# 122                        0  24.64768 -81.65382  24.647714 -81.653949
# 123                     0.75  24.64770 -81.65384  24.647714 -81.653949
# 124                      0.5  24.64770 -81.65386  24.647714 -81.653949
# 125                        0  24.64770 -81.65390  24.647714 -81.653949
# 126                        0  24.64771 -81.65391  24.647714 -81.653949
#
#                        Unnamed: 13
# 0                              NaN
# 4                              NaN
# 8                              NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                             NaN
# 30                             NaN
# 31                             NaN
# 32                             NaN
# 34                             NaN
# 35                             NaN
# 36                             NaN
# 37                             NaN
# 38                             NaN
# 39                             NaN
# ..                             ...
# 82                             NaN
# 83                             NaN
# 84                             NaN
# 85                             NaN
# 86                             NaN
# 87   10s and 100s decimal reversed
# 88                             NaN
# 89                             NaN
# 90                             NaN
# 91                             NaN
# 92                             NaN
# 93                             NaN
# 94                             NaN
# 95                             NaN
# 96                             NaN
# 97                             NaN
# 98                             NaN
# 99                             NaN
# 115                            NaN
# 116                            NaN
# 117                            NaN
# 118                            NaN
# 119                            NaN
# 120                            NaN
# 121                            NaN
# 122                            NaN
# 123                            NaN
# 124                            NaN
# 125                            NaN
# 126                            NaN
#
# [92 rows x 10 columns]

# %%
mud_num
# mud_num = mud_num.drop('Date 1',axis=1)
# Out:
#          Date 1     Date 2 Thickness at Date 1 (cm)  Thickness at Date 2 (cm)  \
# 0    12/20/2017  1/28/2018                        0                      0.00
# 4    12/20/2017  1/28/2018                        0                      0.00
# 8    12/20/2017  1/28/2018                        0                      0.00
# 12   12/19/2017  1/28/2018                        9                      4.00
# 13   12/19/2017  1/28/2018                       11                      6.50
# 14   12/19/2017  1/28/2018                        2                      6.50
# 15   12/19/2017  1/28/2018                        2                      3.00
# 16   12/19/2017  1/28/2018                        5                      3.00
# 17   12/19/2017  1/28/2018                        2                      4.00
# 18   12/19/2017  1/28/2018                        2                      1.00
# 19   12/19/2017  1/28/2018                        3                      4.00
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                             NaN
# 21                             NaN
# 22                             NaN
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             NaN
# 27                             NaN
# 28                             NaN
# 29                             NaN
# 30                             NaN
# 31                             NaN
# 32                             NaN
# 34                             NaN
# 35                             NaN
# 36                             NaN
# 37                             NaN
# 38                             NaN
# 39                             NaN
# ..                             ...
# 82                             NaN
# 83                             NaN
# 84                             NaN
# 85                             NaN
# 86                             NaN
# 87   10s and 100s decimal reversed
# 88                             NaN
# 89                             NaN
# 90                             NaN
# 91                             NaN
# 92                             NaN
# 93                             NaN
# 94                             NaN
# 95                             NaN
# 96                             NaN
# 97                             NaN
# 98                             NaN
# 99                             NaN
# 115                            NaN
# 116                            NaN
# 117                            NaN
# 118                            NaN
# 119                            NaN
# 120                            NaN
# 121                            NaN
# 122                            NaN
# 123                            NaN
# 124                            NaN
# 125                            NaN
# 126                            NaN
#
# [92 rows x 10 columns]

# %%
corr_matrix = mud_num.corr()
corr_matrix['Thickness at Date 1 (cm)'].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Thickness at Date 1 (cm)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-31f0ae1de004> in <module>()
#       1 corr_matrix = mud_num.corr()
# ----> 2 corr_matrix['Thickness at Date 1 (cm)'].sort_values(ascending=False)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Thickness at Date 1 (cm)'

# %%
from pandas.tools.plotting import scatter_matrix
attributes = ['Lat', 'Lon', 'Thickness at Date 1 (cm)']
scatter_matrix(mud_num[attributes], figsize=(12, 9))
mud_num.plot(kind='scatter', x='Thickness at Date 1 (cm)', y='Thickness at Date 2 (cm)', alpha=0.4)
# Out:
# /home/catherinej/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-fc94ccd8a0ef> in <module>()
#       2 attributes = ['Lat', 'Lon', 'Thickness at Date 1 (cm)']
#       3 scatter_matrix(mud_num[attributes], figsize=(12, 9))
# ----> 4 mud_num.plot(kind='scatter', x='Thickness at Date 1 (cm)', y='Thickness at Date 2 (cm)', alpha=0.4)
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1741         if isinstance(data, ABCDataFrame):
#    1742             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1743                              kind=kind, **kwds)
#    1744         else:
#    1745             raise ValueError("plot kind %r can only be used for data frames"
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     843             # the handling of this argument later
#     844             s = 20
# --> 845         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     846         if is_integer(c) and not self.data.columns.holds_integer():
#     847             c = self.data.columns[c]
#
# ~/.local/lib/python3.6/site-packages/pandas/plotting/_core.py in __init__(self, data, x, y, **kwargs)
#     818             y = self.data.columns[y]
#     819         if len(self.data[x]._get_numeric_data()) == 0:
# --> 820             raise ValueError(self._kind + ' requires x column to be numeric')
#     821         if len(self.data[y]._get_numeric_data()) == 0:
#     822             raise ValueError(self._kind + ' requires y column to be numeric')
#
# ValueError: scatter requires x column to be numeric

# %%
imputer.statistics_
mud_num.median().values
x = imputer.transform(mud_num)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-0769473061cb> in <module>()
# ----> 1 imputer.statistics_
#       2 mud_num.median().values
#       3 x = imputer.transform(mud_num)
#
# AttributeError: 'Imputer' object has no attribute 'statistics_'

# %%
mud_num_tr = pd.DataFrame(x, columns=mud_num.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-981f9e654630> in <module>()
# ----> 1 mud_num_tr = pd.DataFrame(x, columns=mud_num.columns)
#
# NameError: name 'x' is not defined

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
mud_cat = mud['Date 1']
mud_cat_encoded = encoder.fit_transform(mud_cat)
mud_cat_encoded
print(encoder.classes_)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-29b20b4f478c> in <module>()
#       2 encoder = LabelEncoder()
#       3 mud_cat = mud['Date 1']
# ----> 4 mud_cat_encoded = encoder.fit_transform(mud_cat)
#       5 mud_cat_encoded
#       6 print(encoder.classes_)
#
# ~/.local/lib/python3.6/site-packages/sklearn/preprocessing/label.py in fit_transform(self, y)
#     125         y = column_or_1d(y, warn=True)
#     126         _check_numpy_unicode_bug(y)
# --> 127         self.classes_, y = np.unique(y, return_inverse=True)
#     128         return y
#     129
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     231     ar = np.asanyarray(ar)
#     232     if axis is None:
# --> 233         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     234         return _unpack_tuple(ret)
#     235
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     276
#     277     if optional_indices:
# --> 278         perm = ar.argsort(kind='mergesort' if return_index else 'quicksort')
#     279         aux = ar[perm]
#     280     else:
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
mud_cat = mud_train_set['Region']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5cc146759984> in <module>()
# ----> 1 mud_cat = mud_train_set['Region']
#
# NameError: name 'mud_train_set' is not defined

# %%
def encode_text(data_frame):
    from sklearn.preprocessing import LabelEncoder
    encoder = LabelEncoder()
    cat = data_frame['Site'] #, 'Region']
    cat_encoded = encoder.fit_transform(cat)
    
    return cat_encoded

# %%
mud_cat = encode_text(mud_train_set)
cat = ['Thickness at Date 1 (cm)', 'Thickness at Date 2 (cm)', 'Date 1', 'Date 2']
df1 = mud_test_set.dropna(subset=cat)
df1 = mud_num.drop('Station', axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-db71b140f01f> in <module>()
# ----> 1 mud_cat = encode_text(mud_train_set)
#       2 cat = ['Thickness at Date 1 (cm)', 'Thickness at Date 2 (cm)', 'Date 1', 'Date 2']
#       3 df1 = mud_test_set.dropna(subset=cat)
#       4 df1 = mud_num.drop('Station', axis=1)
#
# NameError: name 'mud_train_set' is not defined

# %%
def clean_dataframe(dataframe1, dataframe2):
    from sklearn.preprocessing import LabelBinarizer
    lb = LabelBinarizer()
    cat = ['Thickness at Date 1 (cm)', 'Thickness at Date 2 (cm)', 'Date 1', 'Date 2']
    df1 = dataframe1.dropna(subset=cat)
    df2 = dataframe2.dropna(subset=cat)
    df1 = df1.replace('<0.1', 0)
    df1 = df1.replace('<1', .5)
    df2 = df2.replace('<0.1', 0)
    df2 = df2.replace('<1', .5)
    
    drop_columns = ['Date 1', 'Date 2', 'Notes']
    df1 = df1.drop(drop_columns, axis=1) 
    df2 = df2.drop(drop_columns, axis=1)
    
    return df1, df2


def categorize_text(df1, df2):
    categories = df1.select_dtypes(include=[object]).columns
    df1_cat = pd.get_dummies(df1, columns=categories, drop_first=True)
    df2_cat = pd.get_dummies(df2, columns=categories, drop_first=True)
    return df1_cat, df2_cat
#     print(categories)
#     from sklearn.preprocessing import OneHotEncoder, MultiLabelBinarizer
    
#     enc = MultiLabelBinarizer()
#     cat_features = ['Region', 'Site', 'Station']
#     df1_cat = df1[cat_features]
#     df2_cat = df2[cat_features]
#     df1_enc = enc.fit_transform(df1_cat)
#     df2_enc = enc.fit_transform(df2_cat)
    
#     ohe = OneHotEncoder()
#     df1_hot = ohe.fit_transform(df1_enc)
#     df2_hot = ohe.fit_transform(df2_enc)
#     return df1_hot, df2_hot

# train_set = pd.concat([mud_train_set, train_code], axis=1)
train, test = clean_dataframe(mud_train_set, mud_test_set)
print(train)
train_code, test_code = categorize_text(train, test)
print(train_code)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fc0487236c12> in <module>()
#      38
#      39 # train_set = pd.concat([mud_train_set, train_code], axis=1)
# ---> 40 train, test = clean_dataframe(mud_train_set, mud_test_set)
#      41 print(train)
#      42 train_code, test_code = categorize_text(train, test)
#
# NameError: name 'mud_train_set' is not defined

# %%
mud_median = pd.DataFrame.median(train_code['Thickness at Date 1 (cm)'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-b33ccef998ea> in <module>()
# ----> 1 mud_median = pd.DataFrame.median(train_code['Thickness at Date 1 (cm)'])
#
# NameError: name 'train_code' is not defined

# %%
mud_median
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-6ba9be7dac3b> in <module>()
# ----> 1 mud_median
#
# NameError: name 'mud_median' is not defined

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
help(lin_reg.fit)
# lin_reg.fit(train_code, test_code)
# Out:
# Help on method fit in module sklearn.linear_model.base:
#
# fit(X, y, sample_weight=None) method of sklearn.linear_model.base.LinearRegression instance
#     Fit linear model.
#
#     Parameters
#     ----------
#     X : numpy array or sparse matrix of shape [n_samples,n_features]
#         Training data
#
#     y : numpy array of shape [n_samples, n_targets]
#         Target values
#
#     sample_weight : numpy array of shape [n_samples]
#         Individual weights for each sample
#
#         .. versionadded:: 0.17
#            parameter *sample_weight* support to LinearRegression.
#
#     Returns
#     -------
#     self : returns an instance of self.
